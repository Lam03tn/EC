# %%
import cv2 as cv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import random

# %%
dir_path ='data'
daily_path = os.path.join(dir_path,'day')
hourly_path = os.path.join(dir_path,'hour')

daily_data_frames = []
hourly_data_frames = []


for i, area_path in enumerate(os.listdir(daily_path)):
    daily_area_frames = []
    for i,file in enumerate(os.listdir(os.path.join(daily_path,area_path))):
        df = pd.read_csv(os.path.join(daily_path,area_path,file), sep=',') 
        df['t2m']-= 273
        daily_area_frames.append(df)
    daily_data_frames.append(daily_area_frames)

for i, area_path in enumerate(os.listdir(hourly_path)):
    hourly_area_frames = []

    for i,file in enumerate(os.listdir(os.path.join(hourly_path,area_path))):
        df = pd.read_csv(os.path.join(hourly_path,area_path,file), sep=',')  # Using space as separator, skipping first 2 rows
        df['t2m']-= 273
        hourly_area_frames.append(df)
    hourly_data_frames.append(hourly_area_frames)

# %%
len(hourly_area_frames[0])
# Out:
# 8760

# %%
len(hourly_data_frames[0][0])
# Out:
# 8760

# %%
daily_data_frames[0][4]
# Out:
#                      time        t2m  longitude  latitude
# 0     2019-01-01 12:00:00   8.508514        106        21
# 1     2019-01-02 12:00:00  10.144958        106        21
# 2     2019-01-03 12:00:00  12.749298        106        21
# 3     2019-01-04 12:00:00  14.293854        106        21
# 4     2019-01-05 12:00:00  17.171967        106        21
# ...                   ...        ...        ...       ...
# 1821  2023-12-27 12:00:00  14.176178        106        21
# 1822  2023-12-28 12:00:00  15.811005        106        21
# 1823  2023-12-29 12:00:00  17.314026        106        21
# 1824  2023-12-30 12:00:00  17.959625        106        21
# 1825  2023-12-31 12:00:00  18.899963        106        21
#
# [1826 rows x 4 columns]

# %%
daily_df = daily_data_frames[0][0]
for i,df in enumerate(daily_df):
    plt.figure(figsize=(6, 6))
    plt.plot(df['time'], df['t2m'], marker='o')
    plt.title(f'Temperature')
    plt.xlabel('Date')
    plt.ylabel('Temperature')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.grid()
    # plt.ylim(-20, 50)
    plt.tight_layout()  # Adjust layout to prevent clipping of labels
    plt.show()
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 for i,df in enumerate(daily_df):
#       3     plt.figure(figsize=(6, 6))
# ----> 4     plt.plot(df['time'], df['t2m'], marker='o')
#       5     plt.title(f'Temperature')
#       6     plt.xlabel('Date')
#
# TypeError: string indices must be integers, not 'str'

# %%
hourly_df = hourly_data_frames[0][2][0:100]
plt.figure(figsize=(4, 4))
plt.plot(hourly_df['time'], hourly_df['t2m'], marker='o')
plt.title(f'Hourly')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid()
plt.gca().get_xaxis().set_visible(False)
# plt.ylim(-20, 50)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

print(hourly_df['longitude'].unique(), hourly_df['latitude'].unique())
# Out:
# [105] [20]

# %%
daily_df = daily_data_frames[1][4][0:1000]
plt.figure(figsize=(4, 4))
plt.plot(daily_df['time'], daily_df['t2m'], marker='o')
plt.title(f'Daily')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid()
plt.gca().get_xaxis().set_visible(False)
# plt.ylim(-20, 50)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

print(hourly_df['longitude'].unique(), hourly_df['latitude'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 7
#       5 plt.xlabel('Date')
#       6 plt.ylabel('Temperature')
# ----> 7 plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
#       8 plt.grid()
#       9 plt.gca().get_xaxis().set_visible(False)
#
# File c:\Users\LamNH\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2049, in xticks(ticks, labels, minor, **kwargs)
#    2047 labels_out: list[Text] = []
#    2048 if labels is None:
# -> 2049     labels_out = ax.get_xticklabels(minor=minor)
#    2050     for l in labels_out:
#    2051         l._internal_update(kwargs)
#
# File c:\Users\LamNH\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ...

# %%
daily_df = daily_data_frames[3][2]
plt.figure(figsize=(4, 4))
plt.plot(daily_df['time'], daily_df['t2m'], marker='o')
plt.title(f'Daily')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid()
plt.gca().get_xaxis().set_visible(False)
# plt.ylim(-20, 50)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
i = random.randint(0,4)
# Out:
# 1

# %%
for i,hour_area in enumerate(hourly_area_frames):
    for j,hour_location in enumerate(hour_area):
        fault_num = random.randint(0,4)
        
        # no fault
        if i == 0:
            hourly_data_frames[i][j]['']
